# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
# Importing CSV data

filename = 'Data/michael_wellness_data.csv'
def read_csv(filename):
    df = pd.read_csv(filename)
    return df

data = read_csv(filename)
column_headers = data.columns

# %%
drop_headers = ['Thought of the Day', 'Game Notes']

data = data.drop(drop_headers, axis=1)
data
# Out:
#          Date  Day of Week  Whoop Recovery   HRV  Hours of Sleep  Body Weight  \
# 0   4/14/2022            4            99.0  61.0            8.95        174.5
# 1   4/15/2022            5            81.0  51.0            9.05          NaN
# 2   4/16/2022            6            82.0  51.0            8.33          NaN
# 3   4/17/2022            0            76.0  51.0            7.32          NaN
# 4   4/18/2022            1            77.0  51.0            6.92          NaN
# 5   4/19/2022            2             NaN   NaN             NaN          NaN
# 6   4/20/2022            3             NaN   NaN             NaN          NaN
# 7   4/21/2022            4             NaN   NaN             NaN          NaN
# 8   4/22/2022            5             NaN   NaN             NaN          NaN
# 9   4/23/2022            6             NaN   NaN             NaN          NaN
# 10  4/24/2022            0             NaN   NaN             NaN          NaN
# 11  4/25/2022            1             NaN   NaN             NaN          NaN
# 12  4/26/2022            2             NaN   NaN             NaN          NaN
# 13  4/27/2022            3             NaN   NaN             NaN          NaN
# 14  4/28/2022            4             NaN   NaN             NaN          NaN
# 15  4/29/2022            5             NaN   NaN             NaN          NaN
#
#     Body Fat %  Body Water %  Hydration Score (urine)  Sick Feeling  ...  \
# 0          NaN           NaN                      7.0           2.0  ...
# 1          NaN           NaN                      7.0           1.0  ...
# 2          NaN           NaN                      5.0           1.0  ...
# 3          NaN           NaN                      5.0           2.0  ...
# 4          NaN           NaN                      4.0           1.0  ...
# 5          NaN           NaN                      NaN           NaN  ...
# 6          NaN           NaN                      NaN           NaN  ...
# 7          NaN           NaN                      NaN           NaN  ...
# 8          NaN           NaN                      NaN           NaN  ...
# 9          NaN           NaN                      NaN           NaN  ...
# 10         NaN           NaN                      NaN           NaN  ...
# 11         NaN           NaN                      NaN           NaN  ...
# 12         NaN           NaN                      NaN           NaN  ...
# 13         NaN           NaN                      NaN           NaN  ...
# 14         NaN           NaN                      NaN           NaN  ...
# 15         NaN           NaN                      NaN           NaN  ...
#
#     Lift?  Protein Shake?  Fun Rating  Family Love Rating  Tired Rating  \
# 0     0.0             0.0         7.0                 7.0           5.0
# 1     1.0             0.0         2.0                 6.0           8.0
# 2     0.0             0.0         4.0                 6.0           6.0
# 3     0.0             0.0         8.0                 8.0           3.0
# 4     0.0             NaN         NaN                 NaN           NaN
# 5     1.0             NaN         NaN                 NaN           NaN
# 6     NaN             NaN         NaN                 NaN           NaN
# 7     NaN             NaN         NaN                 NaN           NaN
# 8     NaN             NaN         NaN                 NaN           NaN
# 9     NaN             NaN         NaN                 NaN           NaN
# 10    NaN             NaN         NaN                 NaN           NaN
# 11    NaN             NaN         NaN                 NaN           NaN
# 12    NaN             NaN         NaN                 NaN           NaN
# 13    NaN             NaN         NaN                 NaN           NaN
# 14    NaN             NaN         NaN                 NaN           NaN
# 15    NaN             NaN         NaN                 NaN           NaN
#
#     Strain  Alcohol (# of Drinks)  CBD (mg)  Melatonin  Current BA
# 0     15.7                    0.0       0.0        0.0         NaN
# 1     17.5                    0.0       0.0        0.0         NaN
# 2     13.9                    2.0       0.0        0.0         NaN
# 3      5.5                    1.0       0.0        0.0         NaN
# 4      NaN                    NaN       NaN        NaN         NaN
# 5      NaN                    NaN       NaN        NaN         NaN
# 6      NaN                    NaN       NaN        NaN         NaN
# 7      NaN                    NaN       NaN        NaN         NaN
# 8      NaN                    NaN       NaN        NaN         NaN
# 9      NaN                    NaN       NaN        NaN         NaN
# 10     NaN                    NaN       NaN        NaN         NaN
# 11     NaN                    NaN       NaN        NaN         NaN
# 12     NaN                    NaN       NaN        NaN         NaN
# 13     NaN                    NaN       NaN        NaN         NaN
# 14     NaN                    NaN       NaN        NaN         NaN
# 15     NaN                    NaN       NaN        NaN         NaN
#
# [16 rows x 29 columns]

# %%
data = data.dropna(axis=0, thresh=3)
column_headers = data.columns
num_entries = data.shape[0]
data
# Out:
#         Date  Day of Week  Whoop Recovery   HRV  Hours of Sleep  Body Weight  \
# 0  4/14/2022            4            99.0  61.0            8.95        174.5
# 1  4/15/2022            5            81.0  51.0            9.05          NaN
# 2  4/16/2022            6            82.0  51.0            8.33          NaN
# 3  4/17/2022            0            76.0  51.0            7.32          NaN
# 4  4/18/2022            1            77.0  51.0            6.92          NaN
# 5  4/19/2022            2             NaN   NaN             NaN          NaN
#
#    Body Fat %  Body Water %  Hydration Score (urine)  Sick Feeling  ...  \
# 0         NaN           NaN                      7.0           2.0  ...
# 1         NaN           NaN                      7.0           1.0  ...
# 2         NaN           NaN                      5.0           1.0  ...
# 3         NaN           NaN                      5.0           2.0  ...
# 4         NaN           NaN                      4.0           1.0  ...
# 5         NaN           NaN                      NaN           NaN  ...
#
#    Lift?  Protein Shake?  Fun Rating  Family Love Rating  Tired Rating  \
# 0    0.0             0.0         7.0                 7.0           5.0
# 1    1.0             0.0         2.0                 6.0           8.0
# 2    0.0             0.0         4.0                 6.0           6.0
# 3    0.0             0.0         8.0                 8.0           3.0
# 4    0.0             NaN         NaN                 NaN           NaN
# 5    1.0             NaN         NaN                 NaN           NaN
#
#    Strain  Alcohol (# of Drinks)  CBD (mg)  Melatonin  Current BA
# 0    15.7                    0.0       0.0        0.0         NaN
# 1    17.5                    0.0       0.0        0.0         NaN
# 2    13.9                    2.0       0.0        0.0         NaN
# 3     5.5                    1.0       0.0        0.0         NaN
# 4     NaN                    NaN       NaN        NaN         NaN
# 5     NaN                    NaN       NaN        NaN         NaN
#
# [6 rows x 29 columns]

# %% [markdown]
# Neural Network -> Standardize categorical values
# Decision Trees -> Leave as is

# %%
print(column_headers)
# Out:
# Index(['Date', 'Day of Week', 'Whoop Recovery', 'HRV', 'Hours of Sleep',
#        'Body Weight', 'Body Fat %', 'Body Water %', 'Hydration Score (urine)',
#        'Sick Feeling', 'Soreness/Fatigue Score', 'Fitness Rating',
#        'Positivity Score (1-10)', 'Confidence Score', 'Caffeine in mg',
#        'Water Before Coffee?', 'Breakfast Before Coffee?',
#        'Devo Quality (1-10)', 'Game?', 'Lift?', 'Protein Shake?', 'Fun Rating',
#        'Family Love Rating', 'Tired Rating', 'Strain', 'Alcohol (# of Drinks)',
#        'CBD (mg)', 'Melatonin', 'Current BA'],
#       dtype='object')

# %%
target_variables = ['Whoop Recovery', 'HRV', 'Body Weight', 'Current BA']
morning_variables = ['Day of Week', 'Whoop Recovery', 'HRV', 'Hours of Sleep',
                     'Body Weight', 'Body Fat %', 'Body Water %', 'Hydration Score (urine)',
                     'Sick Feeling', 'Soreness/Fatigue Score', 'Fitness Rating',
                     'Positivity Score (1-10)', 'Confidence Score']
night_variables = ['Caffeine in mg',
                   'Water Before Coffee?', 'Breakfast Before Coffee?',
                   'Devo Quality (1-10)', 'Game?', 'Lift?', 'Protein Shake?', 'Fun Rating',
                   'Family Love Rating', 'Tired Rating', 'Strain', 'Alcohol (# of Drinks)',
                   'CBD (mg)', 'Melatonin']

# %%
def update_df(df, morning, night, target):
    if target in night:
        night.remove(target)
    curr_day = df.drop(night, axis=1)
    prev_day = df.drop(morning, axis=1)
    prev_day = df.shift(periods=1)
    return pd.concat([curr_day, prev_day], axis=1)
    
adjusted_df = update_df(data, morning=morning_variables, night=night_variables, target='Whoop Recovery')
adjusted_df
print((adjusted_df.iloc[0,0]))
# Out:
# 4/14/2022

# %%
def standardize(df):
    df = (df-df.mean())/df.std()
    return df
